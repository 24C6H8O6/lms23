# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoonseungwook/lms23/blob/main/230623.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import clear_output
from time import sleep


# won_1 = 충전금액
# take_1 매장이용, 포장 구분
# count = 비할인 금액
# discount = 할인금액
# discountpay = 할인율 적용후 결제금액

#충전 금액 입력
def charge():
    won_1 = int(input("[ 충전 금액을 입력해주세요 ] : "))
    while won_1 < 5000:
        print("최소 금액 5000원이상을 충전해주세요")
        won_1 = int(input("[ 충전 금액을 입력해주세요 ] : "))
    print()
    print()
    print(f"[ 충전이 완료되었습니다 현재 잔액은 {won_1}원 입니다. ]")
    return won_1

won_1 = charge()
sleep(3)
clear_output(wait=True)

# 매장이용/테이크아웃
print("""
        ┌ㅡㅡㅡㅡㅡㅡㅡ┐                     ┌ㅡㅡㅡㅡㅡㅡㅡㅡㅡ┐
        │ 매 장 이 용  │                     │  테 이 크 아 웃  │
        └ㅡㅡㅡㅡㅡㅡㅡ┘                     └ㅡㅡㅡㅡㅡㅡㅡㅡㅡ┘
        """)
print("[ 매장이용시 [1] , 테이크아웃시 [2] ]")
take_1 = int(input("[ 입력해주세요 ] : "))

# 추가사항
list1=[]
list2=[]
list3=[]
# 적립금 초기화
save = 0
# total = 0
# 음료를 큰 카테고리(ctg) 8개로 딕셔너리로 해서 함수로 작성
# def choice_ctg():
#     while True:
#         ctg = input("[음료 카테고리를 선택해주세요]\n[티, 주스&에이드. 아이스 블렌디드, 버블티, X] : ")


menu_tea = {'복숭아 아이스티' : 3000, '유자 허니티' : 3500, '자몽 허니티' : 3500, '레몬 허니티' : 3500, '애플유자티' : 3500, '청글얼그레이' : 2500, '리치캐모마일' : 2500, '트리플민트' : 2500, '애플히비스커스' : 2500, '0':'메뉴 선택 종료'}
menu_normal = {'핫 아메리카노' :1500 , '아이스 아메리카노' : 1800 , '핫 카페라떼' : 2700, '아이스 카페라떼' : 2700, '핫 오트카페라떼' : 3500, '아이스 오트카페라떼' : 3500,
               '핫 믹스커피' : 2300, '아이스 믹스커피' : 2300, '아이스 바닐라딥라떼' : 3500, '핫 바닐라딥라떼' : 3500, '아이스 헤이즐넛딥라떼' : 3500, '핫 헤이즐넛딥라떼' : 3500,
               '핫 연유라떼' : 3500, '핫 카라멜마끼아또' : 3500, '아이스 카라멜마끼아또' : 3500, '핫 카페모카' : 3500, '아이스 카페모카' : 3500, '핫 토피넛라떼' : 3700, '아이스 토피넛라떼' : 3700,
               '핫 꿀다크리카노' : 2300, '아이스 꿀다크리카노' : 2300,'핫 바닐라다크리카노' : 2300, '아이스 바닐라다크리카노' : 2300, '핫 헤이즐넛다크리카노' : 2300, '아이스 헤이즐넛다크리카노' : 2300,
               '핫 아인슈페너' : 3500, '아이스 아인슈페너' : 3500, '0':'메뉴 선택 종료'}
menu_coldbrew = {'콜드브루' : 3300, '콜드브루 라떼' : 3800, '바닐라크림 콜드브루' : 4100, '헤이즐넛크림 콜드브루' : 4100, '0':'메뉴 선택 종료'}
menu_ventisize= {'아메리카노' : 2800, '카페라떼' : 3700, '믹스커피' : 3300, '복숭아 아이스티' : 4000, '0':'메뉴 선택 종료'}
menu_beverage = {'딸기라떼' : 3500, '미숫가루' : 2500, '핫 미숫가루 라떼' : 3000, '아이스 미숫가루 라떼' : 3000, '핫 로얄밀크티' : 3500,
                 '아이스 로얄밀크티' : 3500, '핫초코라떼' : 3000, '아이스초코라떼' : 3000, '핫 녹차라떼' : 3300,
                '아이스 녹차라떼' : 3300, '핫 고구마라떼' : 3500, '아이스 고구마라떼' : 3500, '0':'메뉴 선택 종료'}
menu_juice = {'포블아' : 4300,'망플단' : 4300, '사딸비' : 4300, '오사당' : 4300, '블루레몬 에이드' : 3900,
              '자몽 에이드' : 3900, '청포도 에이드' : 3900, '애플망고 에이드' : 3900, '크림소다' : 3900, '메론소다' : 3900, '체리콕' : 3900, '0':'메뉴 선택 종료'}
menu_blend = {'에스프레소 쉐이크' : 3900, '딸기 쉐이크' : 3900, '밀크 쉐이크' : 3900, '초코 쉐이크' : 3900,  '딸기 요거트스무디 ' : 3900, '플레인 요거트스무디 ' : 3900,
              '블루베리 요거트스무디 ' : 3900, '쿠키앤크림 프라페' : 3900, '코코초코 프라페' : 3900, '코코밀크 프라페' : 3900, '자바칩 프라페' : 3900,
              '초코칩 프라페' : 4200, '토피넛초코칩 프라페' : 4200, '민트초코칩 프라페' : 4200, '딸기초코칩 프라페' : 4200, '말차초코칩 프라페' : 4200, '0':'메뉴 선택 종료'}
menu_bub = {'흑설탕버블티' : 3900, '타로버블티' : 3900, '로얄밀크버블티' : 4300, '청포도 요구르탱' : 3900, '애플망고 요구르탱' : 3900, '딸기 요구르탱' : 3900, '0':'메뉴 선택 종료'}

def select_ctg():
    while True:
        ctg = input("[음료 카테고리를 선택해주세요]\n[커피, 콜드브루, 벤티사이즈, 베버리지, 티, 주스&에이드, 아이스 블렌디드, 버블티] : ")
        if ctg == '커피':
            return menu_normal
        elif ctg == '콜드브루':
            return menu_coldbrew
        elif ctg == '벤티사이즈':
            return menu_ventisize
        elif ctg == '베버리지':
            return menu_beverage
        elif ctg == '티':
            return menu_tea
        elif ctg == '주스&에이드':
            return menu_juice
        elif ctg == '아이스 블렌디드':
            return menu_blend
        elif ctg == '버블티':
            return menu_bub
        elif ctg == '0':
            return '0'
        else:
            print("카테고리가 존재하지 않습니다.다시 입력 해주세요")

# 옵션 큰 항목 4개를 리스트로 만들어서 리스트 따로 작성 후 함수로 작성하여 ####에 추가

# menu_name = ''.join(list(menu_tea.keys()))
# 옵션 3개
# option(wondu_dic)
wondu_dic = {'마일드 원두(2샷)': 0, '다크 원두(2샷)': 0, '디카페인 원두(2샷)': 500,
             '마일드 원두(2샷)+샷추가(2샷)': 500, '다크 원두(2샷)+샷추가(2샷)': 500,
             '디카페인 원두(2샷)+샷추가(2샷)': 1300}
# option(sirub_dic)
sirub_dic = {'달게': 0, '바닐라시럽 추가': 500, '헤이즐넛시럽 추가': 500,
             '흑설탕시럽 추가': 500, '꿀 추가': 500, '연유 추가': 500}
# option(topping_dic)
topping_dic = {'아이스크림 추가': 500, '버블(타피오카펄) 추가': 800, '화이트펄 추가': 800}

# 파라미터로 받은 menu 값 보여주기
def show_menu(menu):
    cnt = 0
    print("="*40)
    for drink, price in menu.items():
        cnt += 1
        print(f'{"":<5}{drink} - {price}원', end='\t')
        if (cnt%3==0):
            print()
    print("="*40)

# 한 메뉴를 두 번 입력하면 생기는 오류 없애기
# 리스트1에 커피명 넣고
# 리스트2에 커피가격 넣고
# 리스트3에 개수를 넣어
# 가격계산할 때는 리스트1의 인덱스에 맞는 리스트2[인덱스]*리스트3[인덱스]
def option(wondu_dic,total):
    while True :
        show_menu(wondu_dic)
        wondu = input('옵션을 골라주세요  🥲 ')
        if wondu in wondu_dic.keys() :
            total += wondu_dic[wondu]
            print("[ 선택하신 메뉴의 가격은 ]", total)
            # list4.append(wondu)
            # list5.append(wondu_dic[wondu])
        elif wondu == '0' :
            print("옵션 추가 완료.")
            break
        else :
            print('옵션에 없습니다.')
    return total


# 카테고리 안에 있는 메뉴
# 한 번 카테고리를 선택하면 다른 카테고리를 선택 못함
# 카테고리를 계속 선택하게끔 하는 함수
def choice(list1,list2,list3):
    while True :
        # 카테고리를 선택하도록
        # 1.카테고리 리스트를 만들어서
        # 2. 카테고리 리스트에 입력한 카테고리 ctg가 있으면
        menu = select_ctg()
        if menu=='0':
            break
        total = 0
        show_menu(menu)
        order = input('메뉴를 골라주세요  🥲 ')
        if order in menu.keys() :
            print(menu[order])
            total += menu[order]
            total = option(wondu_dic,total)
            total = option(sirub_dic,total)
            total = option(topping_dic,total)
            list2.append(total)
            count = int(input('주문할 개수를 선택해주세요 🥲 '))
            total += total*(count-1)
            print(f"[ 선택하신 메뉴의 가격은 총 {total}]")
            list1.append(order)
            list3.append(count)
            print("="*50)
            print("커피명\t\t커피가격\t\t커피개수")
            print("="*50)
            for i in range(len(list1)):
                print(f'{list1[i]}\t{list2[i]}\t{list3[i]}')
            print("="*20)
        elif order == '0' :
            print("주문이 완료되었습니다.")
            break
        else :
            print('메뉴에 없습니다.')
    return [list1,list2,list3]

def show_choice(list1,list2,list3):
    total = 0
    list_total = choice(list1,list2,list3)
    for i in range(len(list_total[0])):
        total += list_total[1][i]*list_total[2][i]
    return list_total,total

# if ctg=='티':
#     list_total,total = show_choice(menu_tea,list1,list2,list3)
#     print(list_total)
#     print(total)
# elif ctg=='주스&에이드':
#     show_menu(menu_juice)
#     list1 = choice(menu_juice,list1,list2,list3)[0]
#     list2 = choice(menu_juice,list1,list2,list3)[1]
#     list3 = choice(menu_juice,list1,list2,list3)[2]
# elif ctg=='아이스 블렌디드':
#     show_menu(menu_blend)
#     list1 = choice(menu_blend,list1,list2,list3)[0]
#     list2 = choice(menu_blend,list1,list2,list3)[1]
#     list3 = choice(menu_blend,list1,list2,list3)[2]
# elif ctg=='버블티':
#     show_menu(menu_bub)
#     list1 = choice(menu_bub,list1,list2,list3)[0]
#     list2 = choice(menu_bub,list1,list2,list3)[1]
#     list3 = choice(menu_bub,list1,list2,list3)[2]


#  여기까지는 잘 출력됨

# won_1 payment 비교
def prt2(won_1, total):
    boolean = True
    while boolean:
        if (won_1 >= total):
            boolean = False
        else:
            # bright red로 출력
            print('\033[31m' + '잔액이 부족합니다!!' + '\033[0m')
            print('\033[31m' + f'{abs(won_1 - total)}원을 충전해주세요!!' + '\033[0m')
            won_2 = int(input("충전할 금액을 입력해주세요!! : "))
            won_1 += won_2
            print(f"{won_2}원이 입금되었습니다. 현재 잔액은 {won_1}입니다.")
    return won_1

list_total, total = show_choice(list1,list2,list3)
# 정가 결제금액 계산
# count = 0 # 일반 결제 금액
# discount = 0 # 할인 결제 금액
# 최종 결제 금액 : payment
if take_1 == 1: # 매장이용
    pass
# 할인된 결제금액 계산
elif take_1 == 2: # 테이크아웃
    discount = int(total*0.15) # 수정필요
    total -= discount
final = prt2(won_1, total)
print(f"[ 결제금액은 {total}원 입니다.]")


# 최종 잔액
final -= total


# 적립할 금액 save
save += total * 0.02

print(f'잔액은 {final}원 이며, 적립 금액은 {save}원 입니다.')
print()

for i in range(len(list1)):
    print(f'{list1[i]}\t{list2[i]}\t{list3[i]}')
# Out:
#         ┌ㅡㅡㅡㅡㅡㅡㅡ┐                     ┌ㅡㅡㅡㅡㅡㅡㅡㅡㅡ┐
#         │ 매 장 이 용  │                     │  테 이 크 아 웃  │
#         └ㅡㅡㅡㅡㅡㅡㅡ┘                     └ㅡㅡㅡㅡㅡㅡㅡㅡㅡ┘
#
# [ 매장이용시 [1] , 테이크아웃시 [2] ]
# [ 입력해주세요 ] : 1
# [음료 카테고리를 선택해주세요]
# [커피, 콜드브루, 벤티사이즈, 베버리지, 티, 주스&에이드, 아이스 블렌디드, 버블티] : 커피
# ========================================
#      핫 아메리카노 - 1500원	     아이스 아메리카노 - 1800원	     핫 카페라떼 - 2700원
#      아이스 카페라떼 - 2700원	     핫 오트카페라떼 - 3500원	     아이스 오트카페라떼 - 3500원
#      핫 믹스커피 - 2300원	     아이스 믹스커피 - 2300원	     아이스 바닐라딥라떼 - 3500원
#      핫 바닐라딥라떼 - 3500원	     아이스 헤이즐넛딥라떼 - 3500원	     핫 헤이즐넛딥라떼 - 3500원
#      핫 연유라떼 - 3500원	     핫 카라멜마끼아또 - 3500원	     아이스 카라멜마끼아또 - 3500원
#      핫 카페모카 - 3500원	     아이스 카페모카 - 3500원	     핫 토피넛라떼 - 3700원
#      아이스 토피넛라떼 - 3700원	     핫 꿀다크리카노 - 2300원	     아이스 꿀다크리카노 - 2300원
#      핫 바닐라다크리카노 - 2300원	     아이스 바닐라다크리카노 - 2300원	     핫 헤이즐넛다크리카노 - 2300원
#      아이스 헤이즐넛다크리카노 - 2300원	     핫 아인슈페너 - 3500원	     아이스 아인슈페너 - 3500원
#      0 - 메뉴 선택 종료원	========================================
# 메뉴를 골라주세요  🥲 핫 아메리카노
# 1500
# ========================================
#      마일드 원두(2샷) - 0원	     다크 원두(2샷) - 0원	     디카페인 원두(2샷) - 500원
#      마일드 원두(2샷)+샷추가(2샷) - 500원	     다크 원두(2샷)+샷추가(2샷) - 500원	     디카페인 원두(2샷)+샷추가(2샷) - 1300원
# ========================================
# 옵션을 골라주세요  🥲 다크 원두(2샷)+샷추가(2샷)
# [ 선택하신 메뉴의 가격은 ] 2000
# ========================================
#      마일드 원두(2샷) - 0원	     다크 원두(2샷) - 0원	     디카페인 원두(2샷) - 500원
#      마일드 원두(2샷)+샷추가(2샷) - 500원	     다크 원두(2샷)+샷추가(2샷) - 500원	     디카페인 원두(2샷)+샷추가(2샷) - 1300원
# ========================================
# 옵션을 골라주세요  🥲 0
# 옵션 추가 완료.
# ========================================
#      달게 - 0원	     바닐라시럽 추가 - 500원	     헤이즐넛시럽 추가 - 500원
#      흑설탕시럽 추가 - 500원	     꿀 추가 - 500원	     연유 추가 - 500원
# ========================================
# 옵션을 골라주세요  🥲 0
# 옵션 추가 완료.
# ========================================
#      아이스크림 추가 - 500원	     버블(타피오카펄) 추가 - 800원	     화이트펄 추가 - 800원
# ========================================
# 옵션을 골라주세요  🥲 0
# 옵션 추가 완료.
# 주문할 개수를 선택해주세요 🥲 3
# [ 선택하신 메뉴의 가격은 총 6000]
# ==================================================
# 커피명		커피가격		커피개수
# ==================================================
# 핫 아메리카노	2000	3
# ====================
# [음료 카테고리를 선택해주세요]
# [커피, 콜드브루, 벤티사이즈, 베버리지, 티, 주스&에이드, 아이스 블렌디드, 버블티] : 티
# ========================================
#      복숭아 아이스티 - 3000원	     유자 허니티 - 3500원	     자몽 허니티 - 3500원
#      레몬 허니티 - 3500원	     애플유자티 - 3500원	     청글얼그레이 - 2500원
#      리치캐모마일 - 2500원	     트리플민트 - 2500원	     애플히비스커스 - 2500원
#      0 - 메뉴 선택 종료원	========================================
# 메뉴를 골라주세요  🥲 복숭아 아이스티
# 3000
# ========================================
#      마일드 원두(2샷) - 0원	     다크 원두(2샷) - 0원	     디카페인 원두(2샷) - 500원
#      마일드 원두(2샷)+샷추가(2샷) - 500원	     다크 원두(2샷)+샷추가(2샷) - 500원	     디카페인 원두(2샷)+샷추가(2샷) - 1300원
# ========================================
# 옵션을 골라주세요  🥲 디카페인 원두(2샷)
# [ 선택하신 메뉴의 가격은 ] 3500
# ========================================
#      마일드 원두(2샷) - 0원	     다크 원두(2샷) - 0원	     디카페인 원두(2샷) - 500원
#      마일드 원두(2샷)+샷추가(2샷) - 500원	     다크 원두(2샷)+샷추가(2샷) - 500원	     디카페인 원두(2샷)+샷추가(2샷) - 1300원
# ========================================
# 옵션을 골라주세요  🥲 0
# 옵션 추가 완료.
# ========================================
#      달게 - 0원	     바닐라시럽 추가 - 500원	     헤이즐넛시럽 추가 - 500원
#      흑설탕시럽 추가 - 500원	     꿀 추가 - 500원	     연유 추가 - 500원
# ========================================
# 옵션을 골라주세요  🥲 0
# 옵션 추가 완료.
# ========================================
#      아이스크림 추가 - 500원	     버블(타피오카펄) 추가 - 800원	     화이트펄 추가 - 800원
# ========================================
# 옵션을 골라주세요  🥲 0
# 옵션 추가 완료.
# 주문할 개수를 선택해주세요 🥲 5
# [ 선택하신 메뉴의 가격은 총 17500]
# ==================================================
# 커피명		커피가격		커피개수
# ==================================================
# 핫 아메리카노	2000	3
# 복숭아 아이스티	3500	5
# ====================
# [음료 카테고리를 선택해주세요]
# [커피, 콜드브루, 벤티사이즈, 베버리지, 티, 주스&에이드, 아이스 블렌디드, 버블티] : 0
# 잔액이 부족합니다!!
# 18500원을 충전해주세요!!
# 충전할 금액을 입력해주세요!! : 20000
# 20000원이 입금되었습니다. 현재 잔액은 25000입니다.
# [ 결제금액은 23500원 입니다.]
# 잔액은 1500원 이며, 적립 금액은 470.0원 입니다.
#
# 핫 아메리카노	2000	3
# 복숭아 아이스티	3500	5

# %%
0
